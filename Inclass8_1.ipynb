# %%
# 2. Install the pyper library.
# !pip install PypeR
# Out:
# ...
# Cleaning up...

# %%
# 3. Import the necessary libraries: pandas, pyper, matplotlib.
import pandas as pd
import pyper as pr
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# 4. Read in the Iris data (csv file on Scholar/Resources/Data) as a pandas DataFrame.
iris = pd.read_csv('iris.csv')

# %%
# 5. Examine the data and get numerical summaries using pandas capabilities: .head(), .shape, .describe, value_counts.
iris.head()
# Out:
#    sepall  sepalw  petall  petalw  Species
# 0     5.1     3.5     1.4     0.2        0
# 1     4.9     3.0     1.4     0.2        0
# 2     4.7     3.2     1.3     0.2        0
# 3     4.6     3.1     1.5     0.2        0
# 4     5.0     3.6     1.4     0.2        0
#
# [5 rows x 5 columns]

# %%
iris.shape
# Out:
# (150, 5)

# %%
iris.describe()
# Out:
#            sepall      sepalw      petall      petalw     Species
# count  150.000000  150.000000  150.000000  150.000000  150.000000
# mean     5.843333    3.054000    3.758667    1.198667    1.000000
# std      0.828066    0.433594    1.764420    0.763161    0.819232
# min      4.300000    2.000000    1.000000    0.100000    0.000000
# 25%      5.100000    2.800000    1.600000    0.300000    0.000000
# 50%      5.800000    3.000000    4.350000    1.300000    1.000000
# 75%      6.400000    3.300000    5.100000    1.800000    2.000000
# max      7.900000    4.400000    6.900000    2.500000    2.000000
#
# [8 rows x 5 columns]

# %%
iris['sepall'].value_counts()
# Out:
# 5.0    10
# 6.3     9
# 5.1     9
# 6.7     8
# 5.7     8
# 5.8     7
# 6.4     7
# 5.5     7
# 6.1     6
# 4.9     6
# 6.0     6
# 5.6     6
# 5.4     6
# 4.8     5
# 6.5     5
# 7.7     4
# 6.2     4
# 6.9     4
# 4.6     4
# 5.2     4
# 6.8     3
# 5.9     3
# 4.4     3
# 7.2     3
# 4.7     2
# 6.6     2
# 7.0     1
# 4.5     1
# 4.3     1
# 7.4     1
# 7.1     1
# 7.9     1
# 7.3     1
# 7.6     1
# 5.3     1
# dtype: int64

# %%
iris['sepalw'].value_counts()
# Out:
# 3.0    26
# 2.8    14
# 3.2    13
# 3.1    12
# 3.4    12
# 2.9    10
# 2.7     9
# 2.5     8
# 3.5     6
# 3.3     6
# 3.8     6
# 2.6     5
# 2.3     4
# 3.6     3
# 2.2     3
# 2.4     3
# 3.7     3
# 3.9     2
# 4.2     1
# 4.4     1
# 4.0     1
# 2.0     1
# 4.1     1
# dtype: int64

# %%
iris['petall'].value_counts()
# Out:
# 1.5    14
# 1.4    12
# 4.5     8
# 5.1     8
# 1.3     7
# 1.6     7
# 5.6     6
# 4.0     5
# 4.7     5
# 4.9     5
# 1.7     4
# 4.4     4
# 4.8     4
# 5.0     4
# 4.2     4
# 6.1     3
# 4.1     3
# 5.7     3
# 5.8     3
# 5.5     3
# 4.6     3
# 3.9     3
# 3.5     2
# 1.2     2
# 6.0     2
# 5.4     2
# 5.3     2
# 4.3     2
# 1.9     2
# 5.9     2
# 3.3     2
# 5.2     2
# 6.7     2
# 6.9     1
# 6.4     1
# 6.6     1
# 3.7     1
# 3.8     1
# 3.0     1
# 1.1     1
# 3.6     1
# 1.0     1
# 6.3     1
# dtype: int64

# %%
iris['petalw'].value_counts()
# Out:
# 0.2    28
# 1.3    13
# 1.8    12
# 1.5    12
# 2.3     8
# 1.4     8
# 0.3     7
# 1.0     7
# 0.4     7
# 2.1     6
# 0.1     6
# 2.0     6
# 1.9     5
# 1.2     5
# 1.6     4
# 2.4     3
# 1.1     3
# 2.2     3
# 2.5     3
# 1.7     2
# 0.6     1
# 0.5     1
# dtype: int64

# %%
iris['Species'].value_counts()
# Out:
# 2    50
# 1    50
# 0    50
# dtype: int64

# %%
# 6. Create an R instance with pyper. Be sure to include the full path to your R installation.
r = pr.R(RCMD = "R", use_pandas = True)

# %%
# 7. Pass data from Python to R.
r.assign("irisR", iris)

# %%
# 8. Now use the “rdata” and R capabilities to: examine the data (head() function, names() function),
#    get numerical summaries (correctly, depending on if a variable is numeric or factor).
print r("head(irisR)")
# Out:
# try({head(irisR)})
#   sepall sepalw petall petalw Species
# 0    5.1    3.5    1.4    0.2       0
# 1    4.9    3.0    1.4    0.2       0
# 2    4.7    3.2    1.3    0.2       0
# 3    4.6    3.1    1.5    0.2       0
# 4    5.0    3.6    1.4    0.2       0
# 5    5.4    3.9    1.7    0.4       0

# %%
print r("names(irisR)")
# Out:
# try({names(irisR)})
# [1] "sepall"  "sepalw"  "petall"  "petalw"  "Species"

# %%
print r("summary(irisR)")
# Out:
# try({summary(irisR)})
#      sepall          sepalw          petall          petalw         Species
#  Min.   :4.300   Min.   :2.000   Min.   :1.000   Min.   :0.100   Min.   :0
#  1st Qu.:5.100   1st Qu.:2.800   1st Qu.:1.600   1st Qu.:0.300   1st Qu.:0
#  Median :5.800   Median :3.000   Median :4.350   Median :1.300   Median :1
#  Mean   :5.843   Mean   :3.054   Mean   :3.759   Mean   :1.199   Mean   :1
#  3rd Qu.:6.400   3rd Qu.:3.300   3rd Qu.:5.100   3rd Qu.:1.800   3rd Qu.:2
#  Max.   :7.900   Max.   :4.400   Max.   :6.900   Max.   :2.500   Max.   :2

# %%
# 9. Access the help file for the R’s princomp function.
print r("?princomp")
# Out:
# try({?princomp})
# princomp                 package:stats                 R Documentation
#
# s
#
# n:
#
#      ‘princomp’ performs a principal components analysis on the given
#      numeric data matrix and returns the results as an object of class
#      ‘princomp’.
#
# e:
#
#      princomp(x, ...)
#
#      ## S3 method for class 'formula'
#      princomp(formula, data = NULL, subset, na.action, ...)
#
#      ## Default S3 method:
#      princomp(x, cor = FALSE, scores = TRUE, covmat = NULL,
#               subset = rep(TRUE, nrow(as.matrix(x))), ...)
#
#      ## S3 method for class 'princomp'
#      predict(object, newdata, ...)
#
# s:
#
#  formula: a formula with no response variable, referring only to
#           numeric variables.
#
#     data: an optional data frame (or similar: see ‘model.frame’)
#           containing the variables in the formula ‘formula’.  By
#           default the variables are taken from ‘environment(formula)’.
#
# ...

# %%
# 10. Calculate the principal components of the iris data and assign the result to an R object that you can name “p”.
r("p <- princomp(irisR)")
# Out:
# 'try({p <- princomp(irisR)})\n'

# %%
# 11. Display the “names” in the object “p”.
print r("names(p)")
# Out:
# try({names(p)})
# [1] "sdev"     "loadings" "center"   "scale"    "n.obs"    "scores"   "call"

# %%
# 12. The actual principal components are saved in the “scores” name in the object “p”. All the
#     principal components are calculated by default (as many as the number of columns in the data
#     set used to calculate the principal components). Display the first 6 rows of the principal
#     components.
print r ("head(p$score])")
# Out:
# try({head(p$scores)})
#      Comp.1     Comp.2       Comp.3       Comp.4        Comp.5
# 0 -2.865507 -0.3027804 -0.048489721  0.076764424  0.0324862994
# 1 -2.893213  0.1769871  0.168798182  0.140958967 -0.0553796651
# 2 -3.055749  0.1680063 -0.056542415  0.043325209  0.0011070839
# 3 -2.921249  0.3250272 -0.009800108 -0.067412716  0.0540828171
# 4 -2.906751 -0.3023327 -0.153720302  0.003524838  0.0756274784
# 5 -2.489000 -0.7397272 -0.200679240 -0.075155520 -0.0003593948

# %%
# 13. Now pass the principal components you have just visualized into a pandas data frame. Be sure
#     to give proper names to columns using the pd.DataFrame’s argument “columns”.
irispc = pd.DataFrame(r.get("p$scores"), columns = ['Comp.1', 'Comp.2', 'Comp.3', 'Comp.4', 'Comp.5'])

# %%
# 14. Examine the newly created pandas dataframe with .head().
irispc.head()
# Out:
#      Comp.1    Comp.2    Comp.3    Comp.4    Comp.5
# 0 -2.865507 -0.302780 -0.048490  0.076764  0.032486
# 1 -2.893213  0.176987  0.168798  0.140959 -0.055380
# 2 -3.055749  0.168006 -0.056542  0.043325  0.001107
# 3 -2.921249  0.325027 -0.009800 -0.067413  0.054083
# 4 -2.906751 -0.302333 -0.153720  0.003525  0.075627
#
# [5 rows x 5 columns]

# %%
# 15. Now create a basic scatterplot of the first two principal components (with matplotlib.pyplot
#     capabilities). Is there a pattern in the data?
plt.scatter(irispc['Comp.1'], irispc['Comp.2'], c = 'blue')
plt.xlabel('First Principal Component')
plt.ylabel('Second Principal Component')

# %%
# Here we see the data separate into three groups, two being fairly distinct from one another and the third (leftmost) being very
# distinct.

# %%
irispc.describe()
# Out:
#              Comp.1        Comp.2        Comp.3        Comp.4        Comp.5
# count  1.500000e+02  1.500000e+02  1.500000e+02  1.500000e+02  1.500000e+02
# mean  -6.291264e-16  4.770258e-16 -7.771561e-18  9.515537e-17 -3.330669e-18
# std    2.198871e+00  5.020820e-01  3.096739e-01  1.915399e-01  1.439641e-01
# min   -3.367572e+00 -1.402547e+00 -7.563396e-01 -5.715186e-01 -3.561339e-01
# 25%   -2.721884e+00 -3.508747e-01 -2.020904e-01 -9.122163e-02 -9.268834e-02
# 50%    5.748873e-01  1.412749e-02 -9.296628e-03  2.536358e-02 -1.433271e-03
# 75%    1.763983e+00  2.916077e-01  2.200132e-01  9.399210e-02  7.559883e-02
# max    3.899296e+00  1.344419e+00  7.147209e-01  3.998584e-01  5.658631e-01
#
# [8 rows x 5 columns]

# %%
""" 16. Next use the example code from last lecture and build the scatterplot for the first two principal
components with the three species differentiated by color. You will have to figure out how to modify the
code slightly to assign different colors to the different species and to display the correct legend.
What patterns do you observe now? Are the first two principal components good at
summarizing the info in the dataset and discriminating between the three species? """

colors = ['blue', 'red', 'lime']
for i in xrange(len(colors)):
    px = irispc['Comp.1'][iris['Species'] == i]
    py = irispc['Comp.2'][iris['Species'] == i]
    plt.scatter(px, py, c=colors[i])
plt.legend(['Species 0', 'Species 1', 'Species 2'])
plt.xlabel('First Principal Component')
plt.ylabel('Second Principal Component')
#
